# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv',encoding='ANSI')
data.head()
# Out:
#    Unnamed: 0   custid                          trade_no bank_card_no  \
# 0           5  2791858  20180507115231274000000023057383          卡号1
# 1          10   534047  20180507121002192000000023073000          卡号1
# 2          12  2849787  20180507125159718000000023114911          卡号1
# 3          13  1809708  20180507121358683000000388283484          卡号1
# 4          14  2499829  20180507115448545000000388205844          卡号1
#
#    low_volume_percent  middle_volume_percent  \
# 0                0.01                   0.99
# 1                0.02                   0.94
# 2                0.04                   0.96
# 3                0.00                   0.96
# 4                0.01                   0.99
#
#    take_amount_in_later_12_month_highest  trans_amount_increase_rate_lately  \
# 0                                      0                               0.90
# 1                                   2000                               1.28
# ...

# %%
y = data['status']
X = data.drop(['status'],axis = 1)
X
# Out:
#       Unnamed: 0   custid                          trade_no bank_card_no  \
# 0              5  2791858  20180507115231274000000023057383          卡号1
# 1             10   534047  20180507121002192000000023073000          卡号1
# 2             12  2849787  20180507125159718000000023114911          卡号1
# 3             13  1809708  20180507121358683000000388283484          卡号1
# 4             14  2499829  20180507115448545000000388205844          卡号1
# 5             15   518072  20180507121233054000000388275132          卡号1
# 6             16  1205125  20180507121931540000000388298915          卡号1
# 7             18  1129897  20180507124659235000000023105807          卡号1
# 8             20  2599411  20180507115855621000000388224458          卡号1
# 9             26  1413051  20180504155156296000000021138084          卡号1
# 10            28   321061  20180507123917136000000388381264          卡号1
# 11            29   750939  20180507121556599000000023080022          卡号1
# ...

# %%
#数据切分方式 - 三七分，其中测试集30%，训练集70%，随机种子设置为2018
from sklearn.model_selection import train_test_split
X_trian, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 2018)

# %%
'''任务1：对数据进行探索和分析。时间：2天
数据类型的分析
无关特征删除
数据类型转换
缺失值处理
……以及你能想到和借鉴的数据分析处理'''
# Out:
# '任务1：对数据进行探索和分析。时间：2天\n数据类型的分析\n无关特征删除\n数据类型转换\n缺失值处理\n……以及你能想到和借鉴的数据分析处理'

# %%
###########Mission1数据探索###################

# %%
#查看前10行
data.head(10)
# Out:
#    Unnamed: 0   custid                          trade_no bank_card_no  \
# 0           5  2791858  20180507115231274000000023057383          卡号1
# 1          10   534047  20180507121002192000000023073000          卡号1
# 2          12  2849787  20180507125159718000000023114911          卡号1
# 3          13  1809708  20180507121358683000000388283484          卡号1
# 4          14  2499829  20180507115448545000000388205844          卡号1
# 5          15   518072  20180507121233054000000388275132          卡号1
# 6          16  1205125  20180507121931540000000388298915          卡号1
# 7          18  1129897  20180507124659235000000023105807          卡号1
# 8          20  2599411  20180507115855621000000388224458          卡号1
# 9          26  1413051  20180504155156296000000021138084          卡号1
#
#    low_volume_percent  middle_volume_percent  \
# 0                0.01                   0.99
# 1                0.02                   0.94
# 2                0.04                   0.96
# ...

# %%
#含有多少个观察值
data.shape[0]
# Out:
# 4754

# %%
#行和列
print(data.shape[0],'行')
print(data.shape[1],'列')
# Out:
# 4754 行
# 90 列

# %%
#所有的列名
data.columns
# Out:
# Index(['Unnamed: 0', 'custid', 'trade_no', 'bank_card_no',
#        'low_volume_percent', 'middle_volume_percent',
#        'take_amount_in_later_12_month_highest',
#        'trans_amount_increase_rate_lately', 'trans_activity_month',
#        'trans_activity_day', 'transd_mcc', 'trans_days_interval_filter',
#        'trans_days_interval', 'regional_mobility', 'student_feature',
#        'repayment_capability', 'is_high_user', 'number_of_trans_from_2011',
#        'first_transaction_time', 'historical_trans_amount',
#        'historical_trans_day', 'rank_trad_1_month', 'trans_amount_3_month',
#        'avg_consume_less_12_valid_month', 'abs',
#        'top_trans_count_last_1_month', 'avg_price_last_12_month',
#        'avg_price_top_last_12_valid_month', 'reg_preference_for_trad',
#        'trans_top_time_last_1_month', 'trans_top_time_last_6_month',
#        'consume_top_time_last_1_month', 'consume_top_time_last_6_month',
#        'cross_consume_count_last_1_month',
# ...

# %%
#数据集的索引
data.index
# Out:
# RangeIndex(start=0, stop=4754, step=1)

# %%
#去掉缺失值
data = data.dropna()
data
# Out:
#       Unnamed: 0   custid                          trade_no bank_card_no  \
# 1             10   534047  20180507121002192000000023073000          卡号1
# 5             15   518072  20180507121233054000000388275132          卡号1
# 9             26  1413051  20180504155156296000000021138084          卡号1
# 11            29   750939  20180507121556599000000023080022          卡号1
# 12            30  1169544  20180507114604230000000388176931          卡号1
# 17            46   829745  20180507123013060000000388346445          卡号1
# 18            48   818730  20180507123317625000000388359399          卡号1
# 20            50  2770676  20180507114736098000000388185623          卡号1
# 24            61   654993  20180507123355168000000388361170          卡号1
# 26            64   148742  20180507120445507000000388245413          卡号1
# 27            71   713652  20180507123830326000000388380639          卡号1
# 28            80  3051745  20180507115610811000000388212340          卡号1
# ...

# %%
#数据类型 分析
for i in data.iloc[0]:
    print(type(i))
# Out:
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.int64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.int64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.int64'>
# <class 'numpy.float64'>
# <class 'numpy.int64'>
# <class 'numpy.float64'>
# <class 'numpy.int64'>
# <class 'numpy.float64'>
# <class 'str'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.int64'>
# <class 'numpy.float64'>
# ...

# %%
##剔除无关数据
data = data.drop('trade_no',axis =1)
data = data.drop('bank_card_no',axis =1)
data
# Out:
#       Unnamed: 0   custid  low_volume_percent  middle_volume_percent  \
# 1             10   534047                0.02                   0.94
# 5             15   518072                0.02                   0.98
# 9             26  1413051                0.01                   0.99
# 11            29   750939                0.01                   0.99
# 12            30  1169544                0.00                   0.73
# 17            46   829745                0.02                   0.98
# 18            48   818730                0.01                   0.99
# 20            50  2770676                0.02                   0.98
# 24            61   654993                0.02                   0.78
# 26            64   148742                0.02                   0.96
# 27            71   713652                0.01                   0.91
# 28            80  3051745                0.01                   0.99
# 45           118  2963712                0.02                   0.98
# ...
